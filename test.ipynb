# %%
from pathlib import Path
import sys
from app.datatransformer import DataTransformer
import dask.array as da
from dask import dataframe as dd
from dask_ml.metrics import mean_squared_error
import time
from dask.distributed import Client
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:52550' processes=4 threads=12, memory=15.21 GiB>

# %%
t = time.time()
data = dd.read_parquet("data/scaled2/", blocksize=4000000)
print('Number of records in data',len(data)/1e9, 'B')
transformer = DataTransformer(train_data=data[['Amount']])
transformer.fit()
transformed_train_data = transformer.transform(data[['Amount']])
transformer.inverse_transform()
amt = dd.read_parquet('data/inverse_transformed/')
mean_squared_error(data[['Amount']].to_dask_array(lengths=True), amt[['Amount']].to_dask_array(lengths=True))
print(time.time() -t)
# Out:
# Number of records in data 1.00481472 B

# %%
amt = dd.read_parquet('data/inverse_transformed/')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask\backends.py:140, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     139 try:
# --> 140     return func(*args, **kwargs)
#     141 except Exception as e:
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask_expr\_collection.py:5471, in read_parquet(path, columns, filters, categories, index, storage_options, dtype_backend, calculate_divisions, ignore_metadata_file, metadata_task_size, split_row_groups, blocksize, aggregate_files, parquet_file_extension, filesystem, engine, arrow_to_pandas, **kwargs)
#    5452     return new_collection(
#    5453         ReadParquetPyarrowFS(
#    5454             path,
#    (...)
#    5467         )
#    5468     )
#    5470 return new_collection(
# -> 5471     ReadParquetFSSpec(
#    5472         path,
#    5473         columns=_convert_to_list(columns),
#    5474         filters=filters,
#    5475         categories=categories,
#    5476         index=index,
#    5477         storage_options=storage_options,
#    5478         calculate_divisions=calculate_divisions,
#    5479         ignore_metadata_file=ignore_metadata_file,
#    5480         metadata_task_size=metadata_task_size,
#    5481         split_row_groups=split_row_groups,
#    5482         blocksize=blocksize,
#    5483         aggregate_files=aggregate_files,
#    5484         parquet_file_extension=parquet_file_extension,
#    5485         filesystem=filesystem,
#    5486         engine=_set_parquet_engine(engine),
#    5487         kwargs=kwargs,
#    5488         _series=isinstance(columns, str),
#    5489     )
#    5490 )
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask_expr\_core.py:59, in Expr.__new__(cls, *args, **kwargs)
#      58 inst.operands = [_unpack_collections(o) for o in operands]
# ---> 59 _name = inst._name
#      60 if _name in Expr._instances:
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\functools.py:993, in cached_property.__get__(self, instance, owner)
#     992 if val is _NOT_FOUND:
# --> 993     val = self.func(instance)
#     994     try:
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask_expr\io\parquet.py:780, in ReadParquet._name(self)
#     774 @cached_property
#     775 def _name(self):
#     776     return (
#     777         self._funcname
#     778         + "-"
#     779         + _tokenize_deterministic(
# --> 780             funcname(type(self)), self.checksum, *self.operands[:-1]
#     781         )
#     782     )
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask_expr\io\parquet.py:786, in ReadParquet.checksum(self)
#     784 @property
#     785 def checksum(self):
# --> 786     return self._dataset_info["checksum"]
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask_expr\io\parquet.py:1364, in ReadParquetFSSpec._dataset_info(self)
#    1345 args = (
#    1346     paths,
#    1347     fs,
#    (...)
#    1362     },
#    1363 )
# -> 1364 dataset_info = self.engine._collect_dataset_info(*args)
#    1365 checksum = []
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask\dataframe\io\parquet\arrow.py:1035, in ArrowDatasetEngine._collect_dataset_info(cls, paths, fs, categories, index, gather_statistics, filters, split_row_groups, blocksize, aggregate_files, ignore_metadata_file, metadata_task_size, parquet_file_extension, kwargs)
#    1034         if len0 and paths == []:
# -> 1035             raise ValueError(
#    1036                 "No files satisfy the `parquet_file_extension` criteria "
#    1037                 f"(files must end with {parquet_file_extension})."
#    1038             )
#    1040 elif len(paths) > 1:
#
# ValueError: No files satisfy the `parquet_file_extension` criteria (files must end with ('.parq', '.parquet', '.pq')).
#
# The above exception was the direct cause of the following exception:
#
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 amt = dd.read_parquet('data/inverse_transformed/')
#
# File c:\Users\suman\data\BD_MLE_assignment\venv\Lib\site-packages\dask\backends.py:151, in CreationDispatch.register_inplace.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     149     raise e
#     150 else:
# --> 151     raise exc from e
#
# ValueError: An error occurred while calling the read_parquet method registered to the pandas backend.
# Original Message: No files satisfy the `parquet_file_extension` criteria (files must end with ('.parq', '.parquet', '.pq')).
