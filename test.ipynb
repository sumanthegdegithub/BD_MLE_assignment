# %%
from pathlib import Path
import sys
from app.datatransformer import DataTransformer
import dask.array as da
from dask import dataframe as dd
from dask_ml.metrics import mean_squared_error
import time
from dask.distributed import Client
from app.create_augmented_data import create_data
client = Client()
client
# Out:
# 2024-12-05 20:40:31,190	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# <Client: 'tcp://127.0.0.1:57598' processes=4 threads=12, memory=15.21 GiB>
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
#Create a data of 1B records
#create_data('data/raw/Credit.csv', 'data/raw')
# Out:
# 100%|██████████| 20064/20064 [22:17<00:00, 15.00it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
list([])
# Out:
# []

# %%
t = time.time()
data = dd.read_csv("data/raw/Credit.csv", blocksize=4000000)
#data = dd.read_parquet("data/scaled2", blocksize=4000000)
#print('Number of records in data',len(data)/1e9, 'B')
transformer = DataTransformer(train_data=data[['Amount']])
transformer.fit()

# %%
t = time.time()
data = dd.read_csv("data/raw/Credit.csv", blocksize=4000000)
#data = dd.read_parquet("data/scaled2", blocksize=4000000)
#print('Number of records in data',len(data)/1e9, 'B')
transformer = DataTransformer(train_data=data[['Amount']])
transformer.fit()
data = dd.read_parquet("data/scaled2", blocksize=4000000)
transformed_train_data = transformer.transform(data[['Amount']])
#transformer.inverse_transform()
amt = dd.read_parquet('data/inverse_transformed/')
mean_squared_error(data[['Amount']].to_dask_array(lengths=True), amt[['Amount']].to_dask_array(lengths=True))
print(time.time() -t)
# Out:
#   7%|▋         | 337/5040 [00:44<10:43,  7.30it/s]
