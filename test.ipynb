# %%
from pathlib import Path
import sys
from app.datatransformer import DataTransformer
import dask.array as da
from dask import dataframe as dd
from dask_ml.metrics import mean_squared_error
import time
from dask.distributed import Client
client = Client()
client
# Out:
# 2024-12-03 23:28:36,010	INFO util.py:154 -- Missing packages: ['ipywidgets']. Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# <Client: 'tcp://127.0.0.1:52583' processes=4 threads=12, memory=15.21 GiB>
# 2024-12-04 00:22:10,192 - distributed.scheduler - WARNING - Worker failed to heartbeat for 904s; attempting restart: <WorkerState 'tcp://127.0.0.1:52602', name: 2, status: running, memory: 0, processing: 0>
# 2024-12-04 00:22:10,194 - distributed.scheduler - WARNING - Worker failed to heartbeat for 904s; attempting restart: <WorkerState 'tcp://127.0.0.1:52605', name: 3, status: running, memory: 0, processing: 0>
# 2024-12-04 00:22:10,195 - distributed.scheduler - WARNING - Worker failed to heartbeat for 904s; attempting restart: <WorkerState 'tcp://127.0.0.1:52606', name: 1, status: running, memory: 0, processing: 0>
# ...

# %%
t = time.time()
data = dd.read_parquet("data/scaled2/", blocksize=4000000)
#data = dd.read_csv("data/raw/Credit.csv", blocksize=4000000)
print('Number of records in data',len(data)/1e9, 'B')
transformer = DataTransformer(train_data=data[['Amount']])
transformer.fit()
transformed_train_data = transformer.transform(data[['Amount']])
transformer.inverse_transform()
amt = dd.read_parquet('data/inverse_transformed/')
mean_squared_error(data[['Amount']].to_dask_array(lengths=True), amt[['Amount']].to_dask_array(lengths=True))
print(time.time() -t)
# Out:
# Number of records in data 1.00481472 B
# ...
# 100%|██████████| 5040/5040 [05:16<00:00, 15.93it/s]
# 2233.392552137375
